# %%
using DifferentialEquations
using Plots
# Out:
# ┌ Info: Recompiling stale cache file /Users/marieandree_ouellet/.julia/compiled/v1.2/DifferentialEquations/UQdwS.ji for DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# └ @ Base loading.jl:1240
# WARNING: Method definition vec(Number) in module FiniteDiff at /Users/marieandree_ouellet/.julia/packages/FiniteDiff/EBys0/src/jacobians.jl:128 overwritten in module DiffEqDiffTools at /Users/marieandree_ouellet/.julia/packages/DiffEqDiffTools/3mm8U/src/jacobians.jl:114.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition vec(Number) in module FiniteDiff at /Users/marieandree_ouellet/.julia/packages/FiniteDiff/EBys0/src/jacobians.jl:128 overwritten in module DiffEqDiffTools at /Users/marieandree_ouellet/.julia/packages/DiffEqDiffTools/3mm8U/src/jacobians.jl:114.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition vec(Number) in module FiniteDiff at /Users/marieandree_ouellet/.julia/packages/FiniteDiff/EBys0/src/jacobians.jl:128 overwritten in module DiffEqDiffTools at /Users/marieandree_ouellet/.julia/packages/DiffEqDiffTools/3mm8U/src/jacobians.jl:114.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition vec(Number) in module FiniteDiff at /Users/marieandree_ouellet/.julia/packages/FiniteDiff/EBys0/src/jacobians.jl:128 overwritten in module DiffEqDiffTools at /Users/marieandree_ouellet/.julia/packages/DiffEqDiffTools/3mm8U/src/jacobians.jl:114.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition __solve(DiffEqBase.DEProblem, Any...) in module DiffEqBase at /Users/marieandree_ouellet/.julia/packages/DiffEqBase/MuYi1/src/solve.jl:174 overwritten in module DifferentialEquations at /Users/marieandree_ouellet/.julia/packages/DifferentialEquations/hztBa/src/default_solve.jl:2.
#   ** incremental compilation may be fatally broken for this module **
#
# WARNING: Method definition #__solve(Any, typeof(DiffEqBase.__solve), DiffEqBase.DEProblem, Any...) in module DiffEqBase overwritten in module DifferentialEquations.
#   ** incremental compilation may be fatally broken for this module **
#
# ┌ Info: Recompiling stale cache file /Users/marieandree_ouellet/.julia/compiled/v1.2/Plots/ld3vC.ji for Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1240

# %%
function allee_strong(n0, p, t)
    n = n0
    dn_dt_n_strong = p.r*((((n/p.A)-1))*(1-(n/p.K)))
    return(dn_dt_n_strong)
end

function allee_weak(n0, p, t)
    n = n0
    dn_dt_n_weak = (p.r*(n^2)/p.K)*(1-(n/p.K))
    return(dn_dt_n_weak)
end

# Initial population sizes
n0 = 10.0

# to - t end
t=(0., 500.)

# Parameters
p = (r = 0.1, A = 50, K = 100)

#Definition du problème
prob_strong = ODEProblem(allee_strong, n0, t, p)
prob_weak = ODEProblem(allee_weak, n0, t, p)

# Résolution du problème
solution_strong = solve(prob_strong)
solution_weak = solve(prob_weak)
# Out:
# retcode: Success
# Interpolation: Automatic order switching interpolation
# t: 22-element Array{Float64,1}:
#    0.0
#    0.25654300857654516
#    2.8219730943419963
#   16.881543795751522
#   39.24880406476008
#   62.10733235493095
#   86.87608489689093
#  109.8054187050618
#  129.06598471228148
#  146.66175929178243
#  162.3083439229357
#  178.50495092216252
#  197.70829336720695
#  220.22184111366317
#  248.7244700504396
#  284.7042154018875
#  327.2909343931132
#  370.6534824421117
#  410.57337053123916
#  446.4910322214865
#  479.67054612279367
#  500.0
# u: 22-element Array{Float64,1}:
#  10.0
#  10.023139324038704
#  10.260212731755972
#  11.771833100638958
#  15.250304426681057
#  21.35462725165691
#  34.73511770016976
#  60.637467401448866
#  86.58494712298474
#  97.0370628864757
#  99.33467281636257
#  99.86274761040042
#  99.9772758223572
#  99.99642950838789
#  99.99891280414002
#  99.99871501205368
#  99.99544882345724
#  99.9814473482328
#  99.9529512971335
#  99.93487761723486
#  99.94455740106142
#  99.99126218785214

# %%
# Plot
plot()
plot(solution_strong, label = "strong")
plot!(solution_weak, label ="weak")

# %%
# évaluation équilibre

function eq_strong(p)
    n\hat = p
    
end

function eq_weak
    
end
